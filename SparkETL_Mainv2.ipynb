# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import split, lower, upper, col, trim, year, month, dayofweek, translate, concat, regexp_replace, \
date_format, date_add
from pyspark.sql.types import StringType , IntegerType
import datetime, math 
import pyspark

spark = SparkSession \
        .builder \
        .appName("Main ETL for the Capstone Project")\
        .getOrCreate()

# %%
#
#
#  ------  PORT LOCATION TABLE
#
#

textFile = spark.sparkContext.textFile("Datasets/Immigration Data/prtlCodes.json")
dfPortCodes = spark.read.json(textFile)
dfStateCode = spark.read.options(header=True, delimiter=',', inferSchema='True').csv("Datasets/States/State_Codes.csv")


nameSplit = split(dfPortCodes.name, ',')
dfPortCodes = dfPortCodes.withColumn('municipality', trim (lower( nameSplit.getItem(0) ) ) ) \
                         .withColumn('statecode', trim (upper( nameSplit.getItem(1) ) ) )

dfPortCodes = dfPortCodes.drop("name")
dfPortCodes = dfPortCodes.filter(dfPortCodes.statecode != 'None')

dfPortCodes = dfPortCodes.join(dfStateCode, dfPortCodes.statecode == dfStateCode["Alpha code"], "left")
dfPortCodes = dfPortCodes.drop("Alpha code").withColumn("State", lower(dfPortCodes.State))

dfPortCodes.createOrReplaceTempView("PORTCODES")


#dfPortCodes.show()
dfPortCodes.filter(dfPortCodes.municipality == 'toronto').toPandas()
# Out:
#   code municipality statecode State
# 0  TOR      toronto    CANADA  None

# %%
#
#
#  ------  AIRPORTS TABLE
#
#

dfAirPorts = spark.read.option("header",True).csv("Datasets/Airport Code/airport-codes_csv.csv")

# Our analysis will be set for US only.
dfAirPorts = dfAirPorts.filter( (dfAirPorts.iso_country == 'US') & (dfAirPorts.type != 'heliport') & (dfAirPorts.type != 'closed') )
latLongSplit = split(dfAirPorts.coordinates, ',')
isoRegSplit = split(dfAirPorts.iso_region, '-')

dfAirPorts = dfAirPorts.withColumn('longitude', latLongSplit.getItem(0)) \
        .withColumn('latitude', latLongSplit.getItem(1)) \
        .withColumn('statecode', upper(isoRegSplit.getItem(1))) \
        .withColumn('municipality', lower(dfAirPorts.municipality)) 

#Remove columns continent and iso_country since it is US only.
dfAirPorts = dfAirPorts.drop("iso_region", "continent", "coordinates", "gps_code", "local_code")

dfAirPorts.createOrReplaceTempView("AIRPORTS_VIEW")

dfAirPortJoinPortLocation = spark.sql("""select * from (
                                      SELECT T1.* , RANK () OVER (PARTITION BY municipality ORDER BY type ASC) as rnk1 FROM  (
                                      SELECT AIR.*, LOC.CODE FROM AIRPORTS_VIEW as AIR 
                                      JOIN PORTCODES as LOC 
                                      ON
                                      AIR.statecode = LOC.statecode
                                      AND
                                      AIR.municipality = LOC.municipality
                                      WHERE TYPE IN ('large_airport', 'medium_airport', 'small_airport')
                                      ) T1
                                      ) where rnk1 = 1
                                      """)

dfAirPortJoinPortLocation.createOrReplaceTempView("AIRPORTS_VIEW2")

dfAirPortJoinPortLocation.toPandas() #711
# Out:
#     ident            type                                 name elevation_ft  \
# 0    KCXL   small_airport       Calexico International Airport            4
# 1    61CL   small_airport             Johnson Brothers Airport           -1
# 2     1RL   small_airport                Point Roberts Airpark           10
# 3    0OI3   small_airport                     Galloway Airport          643
# 4    KPNS  medium_airport           Pensacola Regional Airport          121
# ..    ...             ...                                  ...          ...
# 292  KOGS   small_airport     Ogdensburg International Airport          297
# 293  KSGJ  medium_airport   Northeast Florida Regional Airport           10
# 294  NY69   small_airport                  John Gonzales Field          260
# 295  KSFO   large_airport  San Francisco International Airport           13
# 296  K9U0   small_airport                       Turner Airport         3049
#
#     iso_country   municipality iata_code            longitude  \
# 0            US       calexico       CXL       -115.513000488
# 1            US       calexico      None  -115.55899810791016
# 2            US  point roberts      None   -123.0790023803711
# 3            US       sandusky      None   -82.71610260009766
# 4            US      pensacola       PNS     -87.186599731445
# ..          ...            ...       ...                  ...
# 292          US     ogdensburg       OGS   -75.46549987790002
# 293          US   st augustine       UST           -81.339798
# 294          US   cape vincent      None   -76.30130004882812
# 295          US  san francisco       SFO             -122.375
# 296          US         turner      None  -108.40899658203125
#
#                 latitude statecode CODE  rnk1
# 0          32.6694984436        CA  CAL     1
# 1      32.67340087890625        CA  CAL     1
# 2     48.979698181152344        WA  PIR     1
# 3      41.38209915161133        OH  SDY     1
# 4        30.473400115967        FL  PEN     1
# ..                   ...       ...  ...   ...
# 292        44.6819000244        NY  OGD     1
# 293              29.9592        FL  SAU     1
# 294    44.12009811401367        NY  CAP     1
# 295    37.61899948120117        CA  SFR     1
# 296    48.85419845581055        MT  TUR     1
#
# [297 rows x 12 columns]

# %%
#
#
#  ------  USATEMP  TABLE
#
#

dfTemps = spark.read.options(header=True, delimiter=',', inferSchema='True').csv("Datasets/Tempature/GlobalLandTemperaturesByState.csv")
dfTemps = dfTemps.filter( (dfTemps.Country == 'United States') & (dfTemps.AverageTemperature != 'Nan') )
dfTemps = dfTemps.withColumn('year', year(dfTemps.dt)) \
          .withColumn('month', month(dfTemps.dt))\
          .withColumn('dayOfweek', dayofweek(dfTemps.dt))\
          .withColumn('State', lower (dfTemps.State)) 
          
dfTemps = dfTemps.withColumn("id", concat(translate(dfTemps["dt"], "-" , ""), dfTemps.State ))

dfTemps = dfTemps.drop("dt", "Country")

dfTemps.createOrReplaceTempView("USATEMP")

dfTemps = spark.sql(""" SELECT * FROM USATEMP """)
    
dfTemps.printSchema()
dfTemps.toPandas()
# Out:
# root
#  |-- AverageTemperature: double (nullable = true)
#  |-- AverageTemperatureUncertainty: double (nullable = true)
#  |-- State: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- dayOfweek: integer (nullable = true)
#  |-- id: string (nullable = true)
#         AverageTemperature  AverageTemperatureUncertainty    State  year  \
# 0                   10.722                          2.898  alabama  1743
# 1                   19.075                          2.902  alabama  1744
# 2                   21.197                          2.844  alabama  1744
# 3                   25.290                          2.879  alabama  1744
# 4                   26.420                          2.841  alabama  1744
# ...                    ...                            ...      ...   ...
# 141925              10.607                          0.208  wyoming  2013
# 141926              16.267                          0.276  wyoming  2013
# 141927              20.222                          0.133  wyoming  2013
# 141928              19.621                          0.217  wyoming  2013
# 141929              15.811                          1.101  wyoming  2013
#
#         month  dayOfweek               id
# 0          11          6  17431101alabama
# 1           4          4  17440401alabama
# 2           5          6  17440501alabama
# 3           6          2  17440601alabama
# 4           7          4  17440701alabama
# ...       ...        ...              ...
# 141925      5          4  20130501wyoming
# 141926      6          7  20130601wyoming
# 141927      7          2  20130701wyoming
# 141928      8          5  20130801wyoming
# 141929      9          1  20130901wyoming
#
# [141930 rows x 7 columns]

# %%
#
#
#  ------  USADEMOGRAPHICS  TABLE
#
#

dfCityDemo = spark.read.options(header=True, delimiter=';').csv("Datasets/US Demographics/us-cities-demographics.csv")
dfCityDemo = dfCityDemo.withColumn('City', lower(dfCityDemo.City)) \
                        .withColumn('State', lower(dfCityDemo.State))

dfCityDemo = dfCityDemo.withColumnRenamed('City', 'city')\
                        .withColumnRenamed('State', 'state')\
                        .withColumnRenamed('Median Age', 'median_age')\
                        .withColumnRenamed('Male Population', 'male_population') \
                        .withColumnRenamed('Female Population', 'female_population') \
                        .withColumnRenamed('Total Population', 'total_population') \
                        .withColumnRenamed('Number of Veterans', 'number_of_veterans') \
                        .withColumnRenamed('Foreign-born', 'foreign_born') \
                        .withColumnRenamed('Average Household Size', 'average_household_size') \
                        .withColumnRenamed('State Code', 'state_code')\
                        .withColumnRenamed('Race', 'race')\
                        .withColumnRenamed('Count', 'count') 

dfCityDemo.createOrReplaceTempView("USADEMOGRAPHICS")
dfCityDemo = spark.sql("SELECT * FROM USADEMOGRAPHICS WHERE (state_code, city) in (select statecode, municipality from PORTCODES)")

#dfCityDemo.printSchema()

dfCityDemo.toPandas()
# Out:
#          city      state median_age male_population female_population  \
# 0      duluth  minnesota       34.7           41271             44855
# 1      duluth  minnesota       34.7           41271             44855
# 2      duluth  minnesota       34.7           41271             44855
# 3      duluth  minnesota       34.7           41271             44855
# 4      duluth  minnesota       34.7           41271             44855
# ..        ...        ...        ...             ...               ...
# 546  richmond   virginia       33.6          104793            115496
# 547  richmond   virginia       33.6          104793            115496
# 548  richmond   virginia       33.6          104793            115496
# 549  richmond   virginia       33.6          104793            115496
# 550  richmond   virginia       33.6          104793            115496
#
#     total_population number_of_veterans foreign_born average_household_size  \
# 0              86126               5015         2258                   2.25
# 1              86126               5015         2258                   2.25
# 2              86126               5015         2258                   2.25
# 3              86126               5015         2258                   2.25
# 4              86126               5015         2258                   2.25
# ..               ...                ...          ...                    ...
# 546           220289              12538        15741                   2.29
# 547           220289              12538        15741                   2.29
# 548           220289              12538        15741                   2.29
# 549           220289              12538        15741                   2.29
# 550           220289              12538        15741                   2.29
#
#     state_code                               race   count
# 0           MN                              Asian    1721
# 1           MN  American Indian and Alaska Native    1894
# 2           MN                 Hispanic or Latino    1981
# 3           MN          Black or African-American    3891
# 4           MN                              White   81720
# ..         ...                                ...     ...
# 546         VA                              Asian    6626
# 547         VA          Black or African-American  109722
# 548         VA  American Indian and Alaska Native    4902
# 549         VA                              White  104568
# 550         VA                 Hispanic or Latino   14259
#
# [551 rows x 12 columns]

# %%
#
#
#  ------  IMMIGRATION  TABLE
#
#

dfImmigration = spark.read.options(inferSchema='True').parquet("Datasets/Immigration Data/*.snappy.parquet")

dfImmigration = dfImmigration.filter(dfImmigration["i94mode"] == 1)



dfImmigration = dfImmigration \
                .withColumn("arrdate", regexp_replace(dfImmigration["arrdate"], '\..*$', '').cast(IntegerType()) ) \
                .withColumn("depdate", regexp_replace(dfImmigration["depdate"], '\..*$', '').cast(IntegerType()) )


dfImmigration.createOrReplaceTempView("dateTable")

dfImmigration = spark.sql("""
                    SELECT T1.*, 
                    day(date_add('1960-01-01', arrdate ) ) as arrday,
                    day(date_add('1960-01-01', depdate) ) as depday
                    FROM dateTable T1 
                    """)

dfImmigration = dfImmigration.drop("arrdate","depdate","i94mode","count", "admnum",  \
                                   "entdepa","entdepd","entdepu","matflag","insnum")

dfImmigration.createOrReplaceTempView("dateTable")

dfImmigration = spark.sql("""

                    SELECT * FROM (
                    SELECT count(*) AS CNT, i94port
                    FROM dateTable T1 
                    GROUP BY 
                    i94port HAVING COUNT (*) > 20000
                    ) T1
                    LEFT JOIN AIRPORTS_VIEW2 PC
                    ON 
                    T1.i94port = PC.code
                    ORDER BY CNT DESC
                    """)


#df2.printSchema()
dfImmigration.toPandas()
#df2.count()
# Out:
#        CNT i94port    ident           type  \
# 0   484299     NYC  US-0883  large_airport
# 1   484299     NYC     KLGA  large_airport
# 2   484299     NYC     KJFK  large_airport
# 3   340361     MIA     KMIA  large_airport
# 4   308939     LOS     KLAX  large_airport
# 5   151904     SFR     KSFO  large_airport
# 6   147752     ORL     KSFB  large_airport
# 7   147752     ORL     KMCO  large_airport
# 8   135636     NEW     None           None
# 9   135565     HHW     PHNL  large_airport
# 10  129771     CHI     KORD  large_airport
# 11  129771     CHI     KMDW  large_airport
# 12   99861     HOU     KIAH  large_airport
# 13   99861     HOU     KHOU  large_airport
# 14   93842     FTL     KFLL  large_airport
# 15   92177     ATL     KATL  large_airport
# 16   88102     LVG     KLAS  large_airport
# 17   80875     AGA     None           None
# 18   74420     WAS     None           None
# 19   71473     DAL     KDAL  large_airport
# 20   56863     BOS     KBOS  large_airport
# 21   47084     SEA     KSEA  large_airport
# 22   47084     SEA     KBFI  large_airport
# 23   37707     PHO     KPHX  large_airport
# 24   34597     DET     KDTW  large_airport
# 25   24968     TAM     KTPA  large_airport
# 26   24968     TAM     KMCF  large_airport
# 27   24784     PHI     KPHL  large_airport
# 28   24371     DUB     None           None
# 29   23450     SAI     None           None
# 30   20886     TOR     None           None
#
#                                                  name elevation_ft  \
# 0                                                 JFK         None
# 1                                  La Guardia Airport           21
# 2                John F Kennedy International Airport           13
# 3                         Miami International Airport            8
# 4                   Los Angeles International Airport          125
# 5                 San Francisco International Airport           13
# 6               Orlando Sanford International Airport           55
# 7                       Orlando International Airport           96
# 8                                                None         None
# 9               Daniel K Inouye International Airport           13
# 10               Chicago O'Hare International Airport          672
# 11               Chicago Midway International Airport          620
# 12       George Bush Intercontinental Houston Airport           97
# 13                            William P Hobby Airport           46
# 14    Fort Lauderdale Hollywood International Airport            9
# 15   Hartsfield Jackson Atlanta International Airport         1026
# 16                     McCarran International Airport         2181
# 17                                               None         None
# 18                                               None         None
# 19                                  Dallas Love Field          487
# 20  General Edward Lawrence Logan International Ai...           20
# 21               Seattle Tacoma International Airport          433
# 22     Boeing Field King County International Airport           21
# 23           Phoenix Sky Harbor International Airport         1135
# 24          Detroit Metropolitan Wayne County Airport          645
# 25                        Tampa International Airport           26
# 26                            Mac Dill Air Force Base           14
# 27                 Philadelphia International Airport           36
# 28                                               None         None
# 29                                               None         None
# 30                                               None         None
#
#    iso_country     municipality iata_code            longitude  \
# 0           US         new york      None                    0
# 1           US         new york       LGA         -73.87259674
# 2           US         new york       JFK         -73.77890015
# 3           US            miami       MIA   -80.29060363769531
# 4           US      los angeles       LAX         -118.4079971
# 5           US    san francisco       SFO             -122.375
# 6           US          orlando       SFB   -81.23750305175781
# 7           US          orlando       MCO   -81.30899810791016
# 8         None             None      None                 None
# 9           US         honolulu       HNL          -157.924228
# 10          US          chicago       ORD             -87.9048
# 11          US          chicago       MDW           -87.752403
# 12          US          houston       IAH   -95.34140014648438
# 13          US          houston       HOU         -95.27890015
# 14          US  fort lauderdale       FLL           -80.152702
# 15          US          atlanta       ATL           -84.428101
# 16          US        las vegas       LAS         -115.1520004
# 17        None             None      None                 None
# 18        None             None      None                 None
# 19          US           dallas       DAL           -96.851799
# 20          US           boston       BOS         -71.00520325
# 21          US          seattle       SEA          -122.308998
# 22          US          seattle       BFI    -122.302001953125
# 23          US          phoenix       PHX  -112.01200103759766
# 24          US          detroit       DTW   -83.35340118408203
# 25          US            tampa       TPA        -82.533203125
# 26          US            tampa       MCF         -82.52120209
# 27          US     philadelphia       PHL   -75.24109649658203
# 28        None             None      None                 None
# 29        None             None      None                 None
# 30        None             None      None                 None
#
#                latitude statecode  CODE  rnk1
# 0                     0        NY   NYC   1.0
# 1           40.77719879        NY   NYC   1.0
# 2           40.63980103        NY   NYC   1.0
# 3     25.79319953918457        FL   MIA   1.0
# 4           33.94250107        CA   LOS   1.0
# 5     37.61899948120117        CA   SFR   1.0
# 6    28.777599334716797        FL   ORL   1.0
# 7    28.429399490356445        FL   ORL   1.0
# 8                  None      None  None   NaN
# 9              21.32062        HI   HHW   1.0
# 10              41.9786        IL   CHI   1.0
# 11            41.785999        IL   CHI   1.0
# 12   29.984399795532227        TX   HOU   1.0
# 13          29.64539909        TX   HOU   1.0
# 14            26.072599        FL   FTL   1.0
# 15              33.6367        GA   ATL   1.0
# 16          36.08010101        NV   LVG   1.0
# 17                 None      None  None   NaN
# 18                 None      None  None   NaN
# 19            32.847099        TX   DAL   1.0
# 20          42.36429977        MA   BOS   1.0
# 21            47.449001        WA   SEA   1.0
# 22   47.529998779296875        WA   SEA   1.0
# 23    33.43429946899414        AZ   PHO   1.0
# 24   42.212398529052734        MI   DET   1.0
# 25   27.975500106811523        FL   TAM   1.0
# 26          27.84930038        FL   TAM   1.0
# 27    39.87189865112305        PA   PHI   1.0
# 28                 None      None  None   NaN
# 29                 None      None  None   NaN
# 30                 None      None  None   NaN
